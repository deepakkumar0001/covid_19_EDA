# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style

# %%
new_df=pd.read_csv("/content/covid-variants.csv")

# %%
new_df
# Out:
#       location        date    variant  num_sequences  perc_sequences  \
# 0       Angola  2020-07-06      Alpha              0            0.00
# 1       Angola  2020-07-06  B.1.1.277              0            0.00
# 2       Angola  2020-07-06  B.1.1.302              0            0.00
# 3       Angola  2020-07-06  B.1.1.519              0            0.00
# 4       Angola  2020-07-06    B.1.160              0            0.00
# ...        ...         ...        ...            ...             ...
# 56830   Mexico  2021-05-17     others            256           16.11
# 56831   Mexico  2021-05-17    non_who            997           62.74
# 56832   Mexico  2021-05-31      Alpha            353           20.48
# 56833   Mexico  2021-05-31  B.1.1.277              0            0.00
# 56834   Mexico  2021-05-31  B.1.1.302              0            0.00
#
#        num_sequences_total
# 0                      3.0
# 1                      3.0
# 2                      3.0
# ...

# %% [markdown]
# #Cleaning of data

# %%
new_df.replace(to_replace=0, value=np.NaN, inplace=True)
new_df
# Out:
#       location        date    variant  num_sequences  perc_sequences  \
# 0       Angola  2020-07-06      Alpha            NaN             NaN
# 1       Angola  2020-07-06  B.1.1.277            NaN             NaN
# 2       Angola  2020-07-06  B.1.1.302            NaN             NaN
# 3       Angola  2020-07-06  B.1.1.519            NaN             NaN
# 4       Angola  2020-07-06    B.1.160            NaN             NaN
# ...        ...         ...        ...            ...             ...
# 56830   Mexico  2021-05-17     others          256.0           16.11
# 56831   Mexico  2021-05-17    non_who          997.0           62.74
# 56832   Mexico  2021-05-31      Alpha          353.0           20.48
# 56833   Mexico  2021-05-31  B.1.1.277            NaN             NaN
# 56834   Mexico  2021-05-31  B.1.1.302            NaN             NaN
#
#        num_sequences_total
# 0                      3.0
# 1                      3.0
# 2                      3.0
# ...

# %%
df=new_df.dropna()
df.head(20)
# Out:
#     location        date  variant  num_sequences  perc_sequences  \
# 22    Angola  2020-07-06   others            3.0          100.00
# 23    Angola  2020-07-06  non_who            3.0          100.00
# 34    Angola  2020-08-31     Beta            1.0          100.00
# 58    Angola  2020-09-28     Beta            9.0           90.00
# 70    Angola  2020-09-28   others            1.0           10.00
# 71    Angola  2020-09-28  non_who            1.0           10.00
# 82    Angola  2020-10-12     Beta           24.0           82.76
# 94    Angola  2020-10-12   others            5.0           17.24
# 95    Angola  2020-10-12  non_who            5.0           17.24
# 106   Angola  2020-10-26     Beta            7.0          100.00
# 130   Angola  2020-12-07     Beta            6.0          100.00
# 154   Angola  2020-12-21     Beta           69.0           74.19
# 157   Angola  2020-12-21      Eta            1.0            1.08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9286 entries, 22 to 56832
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   location             9286 non-null   object
#  1   date                 9286 non-null   object
#  2   variant              9286 non-null   object
#  3   num_sequences        9286 non-null   float64
#  4   perc_sequences       9286 non-null   float64
#  5   num_sequences_total  9286 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 507.8+ KB

# %%
df.shape
# Out:
# (9286, 6)

# %%
df.nunique()
# Out:
# location                 70
# date                     45
# variant                  24
# num_sequences          1027
# perc_sequences         2604
# num_sequences_total     829
# dtype: int64

# %%
df.count()
# Out:
# location               9286
# date                   9286
# variant                9286
# num_sequences          9286
# perc_sequences         9286
# num_sequences_total    9286
# dtype: int64

# %% [markdown]
# #Reset of index

# %%
df.reset_index(level=None, drop=False, inplace=True,)
df.style.background_gradient(cmap='Reds')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df.describe()
# Out:
#               index  num_sequences  perc_sequences  num_sequences_total
# count   9286.000000    9286.000000     9286.000000          9286.000000
# mean   27220.510661     233.655395       37.878226          1457.886065
# std    15845.983208    1189.462786       41.571802          3147.918506
# min       22.000000       1.000000        0.010000             1.000000
# 25%    14007.250000       2.000000        1.370000            37.250000
# 50%    27726.500000      11.000000       13.395000           181.000000
# 75%    40709.000000      63.000000       90.910000          1240.000000
# max    56832.000000   28791.000000      100.000000         30285.000000

# %%
df['variant'].unique()
# Out:
# array(['others', 'non_who', 'Beta', 'Eta', 'Alpha', 'B.1.160', 'B.1.177',
#        'B.1.258', 'Kappa', 'B.1.620', 'Gamma', 'Delta', 'B.1.1.519',
#        'Lambda', 'Epsilon', 'Iota', 'Mu', 'Omicron', 'B.1.221',
#        'S:677H.Robin1', 'S:677P.Pelican', 'B.1.367', 'B.1.1.277',
#        'B.1.1.302'], dtype=object)

# %% [markdown]
# #Q.1= Which type of variant register highested time in a particular month ?

# %%
df['date_new']=pd.to_datetime(df['date'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head(2)
# Out:
#    index location        date  variant  num_sequences  perc_sequences  \
# 0     22   Angola  2020-07-06   others            3.0           100.0
# 1     23   Angola  2020-07-06  non_who            3.0           100.0
#
#    num_sequences_total   date_new
# 0                  3.0 2020-07-06
# 1                  3.0 2020-07-06

# %%
df_variant=df['date_new'].dt.month.value_counts().to_frame()
df_variant.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_a30f3_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a30f3_row1_col0 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_a30f3_row2_col0 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_a30f3_row3_col0 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_a30f3_row4_col0 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_a30f3_row5_col0 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_a30f3_row6_col0 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_a30f3_row7_col0 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_a30f3_row8_col0 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_a30f3_row9_col0 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_a30f3_row10_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_a30f3_row11_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# ...

# %% [markdown]
# here we find that 5th month have highest variant registered

# %%
df['date_new'].dt.month.value_counts().plot(kind='bar')
plt.rcParams["figure.figsize"] = (15,8)
plt.title("Month wise total variant")
# Out:
# Text(0.5, 1.0, 'Month wise total variant')

# %% [markdown]
# #Q.2= Which variant register most ?

# %%
df_variant_type=df['variant'].value_counts().to_frame()
df_variant_type.style.background_gradient(cmap='Wistia_r')
# Out:
# <style type="text/css">
# #T_335f1_row0_col0 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# #T_335f1_row1_col0 {
#   background-color: #e6fe74;
#   color: #000000;
# }
# #T_335f1_row2_col0 {
#   background-color: #ffc203;
#   color: #000000;
# }
# #T_335f1_row3_col0 {
#   background-color: #ffc002;
#   color: #000000;
# }
# #T_335f1_row4_col0 {
#   background-color: #ffa100;
#   color: #000000;
# }
# #T_335f1_row5_col0 {
#   background-color: #ff9d00;
#   color: #000000;
# }
# #T_335f1_row6_col0 {
#   background-color: #fe9a00;
#   color: #000000;
# }
# #T_335f1_row7_col0 {
#   background-color: #fe9700;
#   color: #000000;
# }
# #T_335f1_row8_col0 {
#   background-color: #fe9600;
#   color: #000000;
# }
# #T_335f1_row9_col0 {
#   background-color: #fd8f00;
#   color: #f1f1f1;
# }
# #T_335f1_row10_col0, #T_335f1_row11_col0 {
#   background-color: #fd8b00;
#   color: #f1f1f1;
# }
# #T_335f1_row12_col0 {
#   background-color: #fd8900;
#   color: #f1f1f1;
# }
# ...

# %%
df['variant'].value_counts().plot(kind='bar')
plt.rcParams["figure.figsize"] = (10,9)
plt.title("Highest registered variant")
# Out:
# Text(0.5, 1.0, 'Highest registered variant')

# %% [markdown]
# Here we can see that which variant is highest time registered

# %% [markdown]
# #Q.3= find out which country have highest num_sequence with variant type ?

# %%
last_df=df.groupby(["location","variant"])['num_sequences'].sum()

# %%
last_dfs=last_df.sort_values(ascending=False).head(30).to_frame()
last_dfs.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_7bce9_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_7bce9_row1_col0 {
#   background-color: #b21218;
#   color: #f1f1f1;
# }
# #T_7bce9_row2_col0 {
#   background-color: #f96346;
#   color: #f1f1f1;
# }
# #T_7bce9_row3_col0 {
#   background-color: #fb7858;
#   color: #f1f1f1;
# }
# #T_7bce9_row4_col0 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_7bce9_row5_col0 {
#   background-color: #fc8969;
#   color: #f1f1f1;
# }
# #T_7bce9_row6_col0 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_7bce9_row7_col0 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_7bce9_row8_col0 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_7bce9_row9_col0 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_7bce9_row10_col0 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_7bce9_row11_col0 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_7bce9_row12_col0 {
# ...

# %% [markdown]
# Here we can get that which country have highest time of num_sequences in which variant

# %% [markdown]
# #Q.4=Find highest time of num_sequence register on particular date and location ,  which type of variant is that register?

# %%
data_df = df.groupby(['date_new'])['location','num_sequences_total','variant'].max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
data_df1=data_df.sort_values(by=["num_sequences_total",'variant'],ascending=False).head(20)
data_df1.style.background_gradient(cmap="Wistia_r")
# Out:
# <style type="text/css">
# #T_8dc5f_row0_col1 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# #T_8dc5f_row1_col1 {
#   background-color: #ebf962;
#   color: #000000;
# }
# #T_8dc5f_row2_col1 {
#   background-color: #ffe418;
#   color: #000000;
# }
# #T_8dc5f_row3_col1 {
#   background-color: #ffde14;
#   color: #000000;
# }
# #T_8dc5f_row4_col1 {
#   background-color: #ffd20c;
#   color: #000000;
# }
# #T_8dc5f_row5_col1 {
#   background-color: #ffbf01;
#   color: #000000;
# }
# #T_8dc5f_row6_col1, #T_8dc5f_row7_col1 {
#   background-color: #ffba00;
#   color: #000000;
# }
# #T_8dc5f_row8_col1 {
#   background-color: #ffaf00;
#   color: #000000;
# }
# #T_8dc5f_row9_col1 {
#   background-color: #ffaa00;
#   color: #000000;
# }
# #T_8dc5f_row10_col1, #T_8dc5f_row11_col1, #T_8dc5f_row12_col1 {
#   background-color: #ffa600;
#   color: #000000;
# }
# #T_8dc5f_row13_col1 {
#   background-color: #ff9f00;
#   color: #000000;
# }
# #T_8dc5f_row14_col1 {
# ...

# %% [markdown]
# Here we can see that a which type of variant register with highest num_sequence  on particular date and in which country

# %% [markdown]
# This image shows count of variant in worldwide.

# %% [markdown]
# ![covid_image.png](data:image/png;base64,...)
